# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
from scipy.stats import friedmanchisquare

# %% [markdown]
# # **File Path & Load**

# %%
# File load
model_performance_file = "/content/FINAL_RESULT (2).xlsx"
data_reader = pd.ExcelFile(model_performance_file)
all_metrics = data_reader.sheet_names

# %% [markdown]
# # **Friedman Test**

# %%
friedman_results = []

for sheet in all_metrics:
    raw_df = pd.read_excel(data_reader, sheet_name=sheet)

    fold_data = raw_df.iloc[:10]

    target_models = [col for col in fold_data.columns if col.lower() != 'fold']

    model_data_list = [fold_data[model].values for model in target_models]

    try:
        # Friedman Test Calculation
        stat, p_val = friedmanchisquare(*model_data_list)
        friedman_results.append({
            "Evaluation_Metric": sheet,
            "Friedman_Statistic": round(stat, 4),
            "P_Value": round(p_val, 6),
            "Significant": p_val < 0.05
        })
    except Exception as e:
        print(f"Error processing {sheet}: {e}")

friedman_df = pd.DataFrame(friedman_results)

print("\n" + "="*75)
print(f"{'FRIEDMAN TEST':^75}")
print("="*75)
print(friedman_df.to_string(index=False))
print("="*75)

output_file = 'Friedman_Test_Results.xlsx'
friedman_df.to_excel(output_file, index=False)
# Out:
# ===========================================================================
#                                FRIEDMAN TEST
# ===========================================================================
# Evaluation_Metric            Friedman_Statistic                     P_Value  Significant
#          Accuracy 106.3730999999999937699612929 0.0000000000000000000000000         True
#         Precision 108.9846000000000003637978807 0.0000000000000000000000000         True
#            Recall 107.2154000000000024783730623 0.0000000000000000000000000         True
#       Specificity 109.1645000000000038653524825 0.0000000000000000000000000         True
#          F1 Score 107.4414000000000015688783606 0.0000000000000000000000000         True
#           ROC-AUC 107.9671000000000020691004465 0.0000000000000000000000000         True
#               MCC 105.2329000000000007730704965 0.0000000000000000000000000         True
#            G-Mean 106.4449999999999931787897367 0.0000000000000000000000000         True
#             Kappa 106.2627999999999985902832123 0.0000000000000000000000000         True
# ===========================================================================
